# %% [markdown]
# # Spelling Normalizer
# This Google Colab is meant to convert an unnormalized file into its normalized orthography given an ordered list of rules.
#
# **To use**:
#
# - From top to bottom, hover over the left part of each code cell (in brackets). Click the play button tat appears. _Note_: It's important to run them in their order, or you might have unnecessary difficulties!
# - Read the specific text on top of the code cells to check if there are more detailed instructions on what to do.
#
# If you have any questions, feel free to reach out by email: rebeccapattichis2000@gmail.com.
#
# Note, this code is hosted in the following folder: https://drive.google.com/drive/folders/13g3sZX-8Xn4jvGDHAW8v8FlBbq4U_AuF?usp=sharing.

# %% [markdown]
# ## Step 1: Setting Up Environment

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 5.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# **IMPORTANT:** Run the cell below. It is meant to find the path in which the files are located in for your drive. Once it prints an output, go hover to where the play button was and press the stop button!
#
# If you don't do this, it will run for a while.
#
# *Only run this once; once you know this path, you don't need to find it again (and can either delete this cell or skip it in the next runs).*

# %%
# !find 'drive/' -type f -iname 'ProcessCyGr.py'
# Out:
# drive/MyDrive/cyens/CyGr-Project/code/ProcessCyGr.py
# drive/MyDrive/cyens/CyGr-Project/CyGr-Normalizer/code/ProcessCyGr.py
# ^C

# %% [markdown]
# Replace what is in red quotes with the printed output from above, getting rid of the 'ProcessCyGr.py' at the end.

# %%
import sys

sys.path.append('drive/MyDrive/cyens/CyGr-Project/CyGr-Normalizer/code/')
from ProcessCyGr import *

# %% [markdown]
# ## Step 2: Run the Normalizer
# Similar to above, replace the red quotes for the PATH variable with what was printed above, ending at the folder before code/
#
# Also, if applicable, tweak the list of rules to be the rule files desired.

# %%
PATH = 'drive/MyDrive/cyens/CyGr-Project/CyGr-Normalizer/'

rules = ['1-smooth.xlsx', '2-corrections.xlsx', '3-restore.xlsx']
far_tool = ProcessCyGr(PATH + 'data/', PATH + 'spelling-normalizer/', rules)

# %% [markdown]
# Replace original.txt with the name of the file you are wanting to normalize.

# %%
far_tool.find_and_replace('mozilla-original.docx', is_word_doc=True)
